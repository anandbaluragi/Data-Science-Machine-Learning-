# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
x=[1,2,3,4,5,6,7]
y=[10,20,30,20,35,66,77]
plt.plot(x,y)

# %%
x=[1,2,3,4,5,6,7]
y=[10,20,30,20,35,66,77]
plt.plot(x,y,color='red',linewidth=5)

# %%
x=[1,2,3,4,5,6,7]
y=[10,20,30,20,35,66,77]
plt.title('TITLE')
plt.plot(x,y)

# %%
exp_values=[1400,500,300,600,250]
exp_labels=['Home_rent','Food','Phone','Car','Others']
plt.pie(exp_values,labels=exp_values,radius=1,shadow=True,autopct='%0.4f%%',startangle=90,explode=[0,0.2,0,0,0.2])
# Out:
# ([<matplotlib.patches.Wedge at 0x22e15117730>,
# ...
#  [Text(-1.0908949367805172, 0.14123822749748496, '1400'),
#   Text(0.3310723646607339, -1.2571360663659088, '500'),
#   Text(0.9709466408642639, -0.516974487372832, '300'),
#   Text(0.9962725144385929, 0.4663057762608179, '600'),
#   Text(0.33107251178769825, 1.2571360276193602, '250')],
#  [Text(-0.5950336018802821, 0.07703903318044635, '45.9016%'),
#   Text(0.20373683979122081, -0.773622194686713, '16.3934%'),
#   Text(0.5296072586532348, -0.28198608402154474, '9.8361%'),
#   Text(0.5434213715119597, 0.2543486052331734, '19.6721%'),
#   Text(0.2037369303308912, 0.7736221708426831, '8.1967%')])
